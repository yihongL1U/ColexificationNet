# %%
import pickle
import io
from gensim.models import Word2Vec, KeyedVectors

# %%
emb_name = 'sentence_id'

# %%
def load_vec(PATH_TO_FASTTEXT): 
    input_file = io.open(PATH_TO_FASTTEXT, 'r', encoding='utf-8', newline='\n', errors='ignore')
    no_of_words, vector_size = map(int, input_file.readline().split())
    word_to_vector: Dict[str, List[float]] = dict()
    for i, line in enumerate(input_file):
        tokens = line.rstrip().split(' ')
        word = tokens[0]
        vector = list(map(float, tokens[1:]))
        assert len(vector) == vector_size
        word_to_vector[word] = vector
    return word_to_vector

# %%
if emb_name == 'clique_word':
    word_vec = load_vec(f"./{emb_name}.vec")
elif emb_name == 'nt_word':
    word_vec = load_vec(f"./{emb_name}.vec")
elif emb_name == 'sentence_id':
    epochs = 50
    emb_dim = 200
    word_vec = Word2Vec.load(f"./word2vec_{epochs}_{emb_dim}.model")
    word_vec = word_vec.wv

# %%
print(len(word_vec))
# Out:
# 8641799

# %%
type(word_vec.key_to_index)
# Out:
# dict

# %%
from collections import defaultdict
# store the vocabulary for further use:

merged_word_vec = dict()

vocabs = defaultdict(lambda: set())

for key, vec in word_vec.key_to_index.items():
    if len(key.split(':')) == 1:
        vocabs['additional'].add(key)
    elif len(key.split(':')) == 2:
        lang, word = key.split(':')
        if len(lang) == 3:
            pass
        elif len(lang) == 4:
            lang = lang[:3]
        else:
            print(lang)
            raise ValueError("The language code is not right")
        vocabs[lang].add(word)
        
        # merge word vectors
        if f"{lang}:{word}" not in merged_word_vec:
            merged_word_vec[f"{lang}:{word}"] = vec

# %%
wv_from_text = KeyedVectors(vector_size=200)
wv_from_text.add_vectors(list(merged_word_vec.keys()), list(merged_word_vec.values()))

# %%
# print(wv_from_text.most_similar('eng:dogs', topn=1000))

# %%
all_langs = []
for lang, vo in vocabs.items():
#     print(f"{lang}: {len(vo)}")
    all_langs.append(lang)

# %%
print(len(all_langs))
# Out:
# 1336

# %%
print(vocabs['additional'])
# Out:
# {'71036030', '06001006', '19094015', '27006027', '42001073', '18030007', '85008018', '42022017', '69011011', '09018005', '47011028', '09012014', '86012014', '24044026', '19119172', '14010010', '46009010', '07001027', '23015003', '14008012', '66019007', '42001013', '21002011', '09019016', '14002001', '46001002', '45012012', '27006022', '18028010', '07008001', '11018012', '11018025', '47001014', '19018015', '01010015', '44015039', '01001018', '20019003', '80006035', '20020004', '23057012', '25005022', '01017015', '06013009', '70005024', '56001008', '04007069', '26042011', '24028007', '46014007', '46012003', '18033016', '18019016', '42005039', '55004009', '35003013', '24049014', '58012022', '26037027', '16004010', '10021009', '77005063', '66020012', '05028048', '77014002', '05028049', '20023004', '20027001', '14034024', '19040018', '45008035', '11008039', '67005014', '19075005', '85017025', '41005039', '09010015', '68004014', '19136004', '06021033', '40008033', '06015027', '19109017', '44007043', '09022016', '68011008', '77005006', '65001015', '09004012', '06007022', '03007013', '77008003', '71039008', '81001004', '19004001', '04021021', '26016037', '02002018', '19119106', '19099006', '05032045', '09028016', '19040006', '12017001', '43006020', '18038016', '02039025', '39003013', '04026028', '86002042', '19059014', '42022002', '26046005', '61002002', '77014043', '15005001', '20008006', '60002001', '19111002', '52003010', '78014006', '12021015', '81007010', '69004044', '42002040', '23024011', '09025044', '19007005', '40024050', '13022014', '04024024', '16012041', '42013011', '40011006', '19089047', '45003024', '23004006', '66011003', '39001008', '04017013', '07008002', '01024040', '14030008', '26020002', '82002018', '44010035', '82001032', '44007005', '24015014', '18031020', '04030012', '26006011', '45016004', '82012009', '12009028', '20028001', '41001039', '26012023', '27003052', '41005025', '49004019', '10023001', '10019015', '27010001', '01028005', '02034017', '24007002', '02028037', '78002002', '18009012', '19019012', '01034028', '19105028', '19119070', '10022046', '28006002', '18012020', '19012006', '40014010', '03023026', '02002014', '77011031', '19148012', '19081001', '82012034', '42011036', '23010031', '71038017', '68005025', '42009045', '24008022', '05007011', '68003010', '66009009', '23030029', '18039017', '19012002', '40021009', '17008017', '19093002', '32001008', '16007024', '82007068', '71030020', '68016023', '05001026', '05023017', '19005002', '23011005', '01024008', '13013009', '44002023', '03013014', '02028001', '82013022', '43006065', '24002022', '06006011', '77013047', '71030023', '06015041', '01007013', '09008017', '19047008', '43009018', '03025043', '71028017', '15008035', '07009019', '28009009', '10014027', '01024059', '41015010', '80011021', '15004013', '18003026', '41003008', '46004011', '86007045', '85008004', '82006031', '08003006', '14034014', '17003006', '23047009', '78004008', '24005030', '07001018', '24028006', '82007130', '20006027', '51004003', '35002016', '04026005', '01004023', '40008009', '44014007', '03025055', '43011033', '81005050', '41006056', '11001017', '20010025', '02013013', '18033004', '04033002', '20010024', '11012025', '81008063', '80005021', '44018002', '07001032', '19022014', '24027016', '40019017', '04027002', '68012008', '41009046', '09018017', '12022001', '43002002', '19022001', '07010017', '35002017', '24007026', '11007005', '42024016', '13007024', '07013012', '52003005', '46015034', '02008003', '10012012', '41016002', '44013038', '19095004', '81003008', '66004009', '86004002', '11011006', '05012028', '58007018', '60001018', '30002005', '10002016', '67011010', '05019010', '28005010', '14013014', '24036001', '07008025', '19119053', '09025005', '16008012', '20025023', '18034011', '47008023', '42002015', '85017003', '47004014', '09024008', '07001009', '07009012', '77009050', '11018045', '01031030', '06017010', '05010020', '40009021', '19027004', '43003002', '40015015', '07008024', '14 ...

# %%
store_name = f"./stored_vocab/vocab_{emb_name}.pickle"
with open(store_name, 'wb') as handle:
    pickle.dump(dict(vocabs), handle)
print(f"The vocabularies net has been stored in {store_name}!")
# Out:
# The vocabularies net has been stored in ./stored_vocab/vocab_sentence_id.pickle!

# %%
wv_from_text.save(f"word_embeddings_{emb_name}.kv")

# %%
all_langs
# Out:
# ['additional',
#  'ksw',
#  'bsn',
#  'rwo',
#  'hix',
#  'cbu',
#  'toj',
#  'ktj',
#  'crq',
#  'cbv',
#  'crt',
#  'azg',
#  'kpr',
#  'bhl',
#  'mbd',
#  'mtg',
#  'wrs',
#  'nwb',
#  'bch',
#  'gnn',
#  'wbp',
#  'med',
#  'snn',
#  'mxp',
#  'kyz',
#  'rkb',
#  'jpn',
#  'tee',
#  'ots',
#  'por',
#  'tzj',
#  'mhx',
#  'yaq',
#  'yle',
#  'guo',
#  'cak',
#  'bbr',
#  'agt',
#  'mop',
#  'arl',
#  'apn',
#  'deu',
#  'bmh',
#  'muh',
#  'nak',
#  'tzo',
#  'gbr',
#  'lww',
#  'ipi',
#  'mam',
#  'cbt',
#  'ppo',
#  'agu',
#  'nlc',
#  'djr',
#  'ian',
#  'xav',
#  'for',
#  'gbi',
#  'amm',
#  'blw',
#  'mnx',
#  'aaz',
#  'ura',
#  'mcf',
#  'mbi',
#  'mit',
#  'quc',
#  'duo',
#  'cuk',
#  'amu',
#  'szb',
#  'atb',
#  'ign',
#  'msm',
#  'kss',
#  'lac',
#  'kxw',
#  'gvn',
#  'tpz',
#  'gnb',
#  'ivb',
#  'sqi',
#  'nuy',
#  'neb',
#  'kmh',
#  'aso',
#  'aln',
#  'mtp',
#  'ozm',
#  'khs',
#  'pad',
#  'tfr',
#  'dgc',
#  'mif',
#  'kyf',
#  'hla',
#  'cbc',
#  'aly',
#  'ncu',
#  'udu',
#  'tlf',
#  'tob',
#  'spl',
#  'sll',
#  'xed',
#  'tca',
#  'mzl',
#  'atd',
#  'nab',
#  'daa',
#  'cni',
#  'bcw',
#  'cjo',
#  'fij',
#  'myu',
#  'geb',
#  'att',
#  'mir',
#  'yml',
#  'cac',
#  'kno',
#  'avu',
#  'byx',
#  'gud',
#  'mfk',
#  'noa',
#  'crn',
#  'mya',
#  'ita',
#  'tuc',
#  'ldi',
#  'ncl',
#  'cok',
#  'agd',
#  'enx',
#  'abx',
#  'hvn',
#  'afr',
#  'bfo',
#  'dgi',
#  'acr',
#  'poh',
#  'naq',
#  'chf',
#  'tzh',
#  'knv',
#  'kto',
#  'mfh',
#  'hag',
#  'lid',
#  'bfd',
#  'djk',
#  'yby',
#  'gnd',
#  'xtm',
#  'mps',
#  'taq',
#  'sgb',
#  'cut',
#  'nnw',
#  'ndi',
#  'cgc',
#  'muy',
#  'gde',
#  'ell',
#  'sba',
#  'csy',
#  'ese',
#  'mqb',
#  'qvs',
#  'maq',
#  'cag',
#  'mhi',
#  'gej',
#  'sbd',
#  'mcd',
#  'giz',
#  'mvn',
#  'bom',
#  'opm',
#  'mzh',
#  'tos',
#  'cbr',
#  'ces',
#  'cux',
#  'sua',
#  'myw',
#  'bkq',
#  'eri',
#  'bwu',
#  'las',
#  'okv',
#  'mwm',
#  'meq',
#  'nfa',
#  'cko',
#  'pao',
#  'tlb',
#  'roo',
#  'cnt',
#  'gdg',
#  'yre',
#  'xrb',
#  'fon',
#  'tuo',
#  'due',
#  'itv',
#  'tik',
#  'mbl',
#  'gng',
#  'obo',
#  'mwq',
#  'spy',
#  'tpi',
#  'bib',
#  'kdl',
#  'miz',
#  'ape',
#  'hat',
#  'ojs',
#  'guw',
#  'pri',
#  'tby',
#  'aon',
#  'wca',
#  'mto',
#  'ayo',
#  'ald',
#  'mkn',
#  'srq',
#  'smk',
#  'caa',
#  'mbs',
#  'kjb',
#  'leg',
#  'bgs',
#  'taw',
#  'kpw',
#  'inb',
#  'xsu',
#  'msb',
#  'bcl',
#  'kup',
#  'jbu',
#  'kgp',
#  'ixl',
#  'kqp',
#  'xbr',
#  'amn',
#  'agw',
#  'zpc',
#  'ifu',
#  'cbk',
#  'way',
#  'kpj',
#  'zpm',
#  'bon',
#  'lsi',
#  'yad',
#  'cub',
#  'mbb',
#  'trq',
#  'cme',
#  'bjv',
#  'fra',
#  'ctp',
#  'ctu',
#  'xtd',
#  'txu',
#  'gkp',
#  'ons',
#  'alq',
#  'plg',
#  'knj',
#  'pio',
#  'zam',
#  'awi',
#  'nii',
#  'aau',
#  'nvm',
#  'tpp',
#  'yuj',
#  'ify',
#  'ceb',
#  'gso',
#  'gah',
#  'tna',
#  'mox',
#  'trc',
#  'cjv',
#  'aeu',
#  'mil',
#  'wnc',
#  'akh',
#  'fai',
#  'kac',
#  'gym',
#  'pah',
#  'gvl',
#  'cao',
#  'zca',
#  'eka',
#  'dhm',
#  'lex',
#  'pbi',
#  'azz',
#  'tnn',
#  'npy',
#  'ewe',
#  'jac',
#  'dah',
#  'ebk',
#  'kbh',
#  'kbp',
#  'zao',
#  'bbb',
#  'sag',
#  'zpu',
#  'tcs',
#  'eza',
#  'stp',
#  'ken',
#  'bvr',
#  'cnl',
#  'yon',
#  'maz',
#  'stn',
#  'mrw',
#  'mtj',
#  'bss',
#  'yaa',
#  'vut',
#  'kqo',
#  'sun',
#  'bvz',
#  'mna',
#  'asg',
#  'smo',
#  'gaw',
#  'nmz',
#  'ood',
#  'lip',
#  'bps',
#  'biv',
#  'ivv',
#  'mor',
#  'lbk',
#  'mco',
#  'rmo',
#  'kkj',
#  'ksc',
#  'niy',
#  'caf',
#  'mbt',
#  'qve',
#  'poe',
#  'pon',
#  'mmn',
#  'guh',
#  'kvn',
#  'nhu',
#  'dtp',
#  'cpu',
#  'apy',
#  'prf',
#  'kgk',
#  'qvc',
#  'hto',
#  'kyq',
#  'mri',
#  'ifa',
#  'myx',
#  'guc',
#  'gur',
#  'cul',
#  'tac',
#  'agn',
#  'not',
#  'cco',
#  'bdh',
#  'mda',
#  'zpt',
#  'kek',
#  'yor',
#  'aom',
#  'zsr',
#  'kne',
#  'mlp',
#  'aia',
#  'mva',
#  'wap',
#  'mzk',
#  'upv',
#  'yuw',
#  'ilb',
#  'kaq',
#  'hot',
#  'zty',
#  'sue',
#  'kwd',
#  'tqb',
#  'ame',
#  'gub',
#  'cnh',
#  'bao',
#  'mee',
#  'gkn',
#  'lcm',
#  'cso',
#  'blh',
#  'snc',
#  'crm',
#  'bpr',
#  'cym',
#  'bzd',
#  'kpg',
#  'sps',
#  'nct',
#  'efi',
#  'otm',
#  'ycn',
#  'mfz',
#  'xuo',
#  'qup',
#  'ssg',
#  'nus',
#  'zaa',
#  'maw',
#  'ifb',
#  'spp',
#  'nho',
#  'iri',
#  'mos',
#  'amr',
#  'leh',
#  'mta',
#  'xho',
#  'tav',
#  'pes',
#  'sri',
#  'bmq',
#  'maa',
#  'iws',
#  'knk',
#  'poi',
#  'pap',
#  'mib',
#  'cav',
#  'arn',
#  'prs',
#  'bci',
#  'irk',
#  'nfr',
#  'acf',
#  'xla',
#  'msa',
#  'dyu',
#  'cpc',
#  'rop',
#  'apr',
#  'atg',
#  'sab',
#  'gun',
#  'kwf',
#  'quf',
#  'dyi',
#  'chd',
#  'mau',
#  'mbj',
#  'yss',
#  'icr',
#  'dik',
#  'haw',
#  'wwa',
#  'tbl',
#  'boj',
#  'kyu',
#  'tso',
#  'gjn',
#  'nin',
#  'taj',
#  'msy',
#  'wob',
#  'gil',
#  'ctd',
#  'gqr',
#  'plw',
#  'gdn',
#  'dts',
#  'sey',
#  'mpm',
#  'mig',
#  'cas',
#  'pib',
#  'anv',
#  'bud',
#  'yuz',
#  'leu',
#  'iou',
#  'luo',
#  'csk',
#  'apu',
#  'qxo',
#  'ann',
#  'acd',
#  'alj',
#  'rai',
#  'bum',
#  'kmk',
#  'sbl',
#  'ong',
#  'rmy',
#  'adj',
#  'kmo',
#  'crs',
#  'ote',
#  'kms',
#  'tbg',
#  'zia',
#  'nso',
#  'ssx',
#  'tue',
#  'dnj',
#  'beq',
#  'sgz',
#  'zae',
#  'faa',
#  'gaa',
#  'bex',
#  'dan',
#  'miy',
#  'urd',
#  'maf',
#  'otn',
#  'lef',
#  'shi',
#  'ind',
#  'msk',
#  'hch',
#  'vag',
#  'mnh',
#  'zpv',
#  'bnp',
#  'lom',
#  'eng',
#  'dug',
#  'khm',
#  'gdr',
#  'mbh',
#  'toc',
#  'zho',
#  'mcu',
#  'lif',
#  'hun',
#  'lee',
#  'aoj',
#  'hwc',
#  'bmb',
#  'kao',
#  'mur',
#  'srm',
#  'kdi',
#  'cpb',
#  'clu',
#  'che',
#  'wnu',
#  'qvi',
#  'kog',
#  'kqs',
#  'snp',
#  'mfi',
#  'myy',
#  'abt',
#  'lmp',
#  'sml',
#  'ppk',
#  'pls',
#  'kjh',
#  'bnj',
#  'bim',
#  'sot',
#  'pan',
#  'tsn',
#  'kde',
#  'ntr',
#  'sil',
#  'mbf',
#  'kqe',
#  'czt',
#  'kqy',
#  'xsi',
#  'yal',
#  'srn',
#  'kwj',
#  'hub',
#  'loz',
#  'xsm',
#  'ata',
#  'agg',
#  'mpt',
#  'swe',
#  'nhw',
#  'heg',
#  'iqw',
#  'amp',
#  'nmo',
#  'aak',
#  'lia',
#  'nhe',
#  'ubr',
#  'pmf',
#  'otq',
#  'tgl',
#  'izr',
#  'chq',
#  'mav',
#  'gvf',
#  'zpz',
#  'mio',
#  'pab',
#  'cbs',
#  'zpo',
#  'hus',
#  'urb',
#  'ssd',
#  'kje',
#  'kma',
#  'aby',
#  'mwv',
#  'men',
#  'cta',
#  'cpy',
#  'gux',
#  'big',
#  'trn',
#  'nyf',
#  'avt',
#  'kpz',
#  'imo',
#  'jam',
#  'ztq',
#  'bem',
#  'bkd',
#  'kkc',
#  'zyp',
#  'biu',
#  'nwi',
#  'mza',
#  'tir',
#  'mej',
#  'mxb',
#  'chk',
#  'soq',
#  'sig',
#  'bef',
#  'kbm',
#  'kbc',
#  'adh',
#  'hif',
#  'rus',
#  'ptp',
#  'yam',
#  'nch',
#  'zab',
#  'nld',
#  'cjp',
#  'sim',
#  'kez',
#  'lsm',
#  'twi',
#  'suk',
#  'qug',
#  'tgp',
#  'wsk',
#  'nob',
#  'tpm',
#  'cof',
#  'kpx',
#  'pcm',
#  'mjc',
#  'ncj',
#  'hil',
#  'cot',
#  'mcn',
#  'hlt',
#  'fil',
#  'tum',
#  'huv',
#  'boa',
#  'zar',
#  'auc',
#  'dur',
#  'nbl',
#  'quh',
#  'shk',
#  'qul',
#  'aim',
#  'omw',
#  'lhm',
#  'qxn',
#  'kub',
#  'kan',
#  'nde',
#  'apb',
#  'dow',
#  'mnf',
#  'zos',
#  'hnn',
#  'lem',
#  'bth',
#  'sny',
#  'kdj',
#  'nyn',
#  'jic',
#  'mxt',
#  'ven',
#  'gya',
#  'pwg',
#  'kxm',
#  'wol',
#  'amk',
#  'tar',
#  'mcp',
#  'mhl',
#  'nnh',
#  'kwi',
#  'btt',
#  'mca',
#  'myk',
#  'dyo',
#  'cpa',
#  'dad',
#  'pol',
#  'bav',
#  'sxb',
#  'enb',
#  'bru',
#  'oss',
#  'sin',
#  'npl',
#  'gnw',
#  'gui',
#  'ake',
#  'gyr',
#  'bbj',
#  'tha',
#  'cle',
#  'ksd',
#  'ikk',
#  'ksf',
#  'kvj',
#  'bkv',
#  'gog',
#  'qvh',
#  'prk',
#  'mnk',
#  'wbm',
#  'kik',
#  'tlh',
#  'nya',
#  'ilo',
#  'lwo',
#  'hrv',
#  'pis',
#  'whk',
#  'pdc',
#  'shp',
#  'soy',
#  'sld',
#  'mfq',
#  'apz',
#  'cbi',
#  'niq',
#  'ghe',
#  'gbo',
#  'hmo',
#  'mpx',
#  'btd',
#  'mxq',
#  'vmy',
#  'tab',
#  'crx',
#  'top',
#  'mkl',
#  'ndc',
#  'lhu',
#  'tuf',
#  'twu',
#  'ntp',
#  'kxc',
#  'mbc',
#  'swp',
#  'bjr',
#  'pne',
#  'kaz',
#  'sna',
#  'fry',
#  'bzj',
#  'nph',
#  'urk',
#  'kia',
#  'nbc',
#  'pbb',
#  'fuf',
#  'fal',
#  'gid',
#  'lew',
#  'con',
#  'hau',
#  'sja',
#  'acu',
#  'heh',
#  'iry',
#  'pww',
#  'zpq',
#  'sur',
#  'cmo',
#  'uvl',
#  'pag',
#  'tbz',
#  'tku',
#  'bgr',
#  'gul',
#  'nas',
#  'lhi',
#  'krc',
#  'bar',
#  'bis',
#  'war',
#  'lus',
#  'agr',
#  'sxn',
#  'npo',
#  'ace',
#  'bqj',
#  'kri',
#  'cwt',
#  'dww',
#  'car',
#  'mks',
#  'nhx',
#  'etu',
#  'nhr',
#  'are',
#  'tim',
#  'spa',
#  'vun',
#  'vie',
#  'pse',
#  'mlh',
#  'cax',
#  'yua',
#  'moc',
#  'ach',
#  'ukr',
#  'khz',
#  'qwh',
#  'cya',
#  'apt',
#  'zom',
#  'mcq',
#  'laj',
#  'ubu',
#  'ngc',
#  'cce',
#  'cfm',
#  'acn',
#  'lam',
#  'pbl',
#  'awa',
#  'viv',
#  'mzm',
#  'yut',
#  'epo',
#  'zas',
#  'ino',
#  'ter',
#  'dis',
#  'bdd',
#  'min',
#  'qvm',
#  'lbj',
#  'krj',
#  'kum',
#  'ory',
#  'mti',
#  'waj',
#  'dip',
#  'hin',
#  'gfk',
#  'bug',
#  'wos',
#  'btx',
#  'isl',
#  'miq',
#  'tcz',
#  'qxh',
#  'izz',
#  'nbe',
#  'ikw',
#  'kew',
#  'kud',
#  'nsn',
#  'gle',
#  'nhg',
#  'mpg',
#  'cly',
#  'buk',
#  'mek',
#  'kir',
#  'kaa',
#  'nng',
#  'dob',
#  'dgr',
#  'ptu',
#  'mcb',
#  'mux',
#  'amf',
#  'hui',
#  'rro',
#  'mzw',
#  'zad',
#  'usa',
#  'sgw',
#  'ttc',
#  'fuh',
#  'zpi',
#  'som',
#  'njb',
#  'ndz',
#  'kyg',
#  'mqy',
#  'kki',
#  'bku',
#  'esu',
#  'dop',
#  'dgz',
#  'cop',
#  'tcc',
#  'jae',
#  'ffm',
#  'ike',
#  'mar',
#  'ajz',
#  'gmv',
#  'poy',
#  'kor',
#  'hns',
#  'guk',
#  'ifk',
#  'aai',
#  'snd',
#  'fub',
#  'ben',
#  'awb',
#  'cap',
#  'kze',
#  'gwi',
#  'sas',
#  'kpf',
#  'syc',
#  'arb',
#  'nhd',
#  'jav',
#  'njn',
#  'kpv',
#  'gor',
#  'yrb',
#  'gvc',
#  'myv',
#  'cha',
#  'eus',
#  'hnj',
#  'mdy',
#  'guq',
#  'xon',
#  'mww',
#  'kat',
#  'jiv',
#  'enm',
#  'amh',
#  'lug',
#  'pir',
#  'fuv',
#  'mlt',
#  'kbq',
#  'kbr',
#  'ron',
#  'nyo',
#  'zul',
#  'aey',
#  'bul',
#  'slk',
#  'zac',
#  'shu',
#  'lgm',
#  'tui',
#  'nnq',
#  'lit',
#  ...]
